# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train_2.csv')
test=pd.read_csv('key_2.csv')

# %%
train.shape
# Out:
# (145063, 804)

# %%
# test file beginning date: 2017-09-13
test.iloc[0][0]
# Out:
# '007_スペクター_ja.wikipedia.org_all-access_all-agents_2017-09-13'

# %%
# test file ending date inclusive:2017-11-13
test.iloc[-1][0]
# Out:
# '龙生九子_zh.wikipedia.org_mobile-web_all-agents_2017-11-13'

# %%
train.iloc[:,-10:]
# Out:
#         2017-09-01  2017-09-02  2017-09-03  2017-09-04  2017-09-05  \
# 0             19.0        33.0        33.0        18.0        16.0
# 1             32.0        30.0        11.0        19.0        54.0
# 2              6.0         6.0         7.0         2.0         4.0
# 3              7.0        19.0        19.0         9.0         6.0
# 4             16.0        16.0        19.0         9.0        20.0
# 5             13.0        13.0        45.0         4.0        13.0
# 6             12.0         8.0         5.0         7.0         8.0
# 7             74.0        39.0        11.0        55.0        71.0
# 8             53.0       107.0        63.0        42.0        24.0
# 9             20.0        16.0        22.0        19.0        21.0
# 10            17.0        17.0        25.0         4.0        29.0
# 11            10.0        13.0         8.0        16.0         6.0
# 12             7.0         4.0         5.0        10.0         7.0
# ...

# %%
nick=pd.read_csv('submission6.csv')
len(nick)
# Out:
# 8993906

# %%
mysub=pd.read_csv('sub_mads_windows_0.28.csv')
len(mysub)
# Out:
# 8993906

# %%
len(test)
# Out:
# 8993906

# %%
nick.tail(200)
# Out:
#                    Id  Visits
# 8993706  be4fd4c5da0b     105
# 8993707  1e4f74e03574     105
# 8993708  0796811b4fe3     105
# 8993709  0990196aea5d     105
# 8993710  3222d01e18e4     105
# 8993711  4a07dfbfcc16     105
# 8993712  e1fc9c153a4d     105
# 8993713  78f7e09e2b6b     105
# 8993714  b7bec7defde7     105
# 8993715  bd5f46d6eaac     105
# 8993716  1b436c7108eb     105
# 8993717  8f57864a709c     105
# 8993718  a8f2aa21e501     105
# 8993719  85b4305462e7     105
# 8993720  360d9cf6d643     114
# 8993721  7523ce121ed9     114
# 8993722  1cb4fb78a570     114
# 8993723  45f55f02687e     114
# 8993724  8faa3078d19b     114
# 8993725  6627c9e4b49a     114
# 8993726  d716d8666920     114
# 8993727  0341a9e25cec     114
# 8993728  76a98c3a237e     114
# 8993729  616484bad8e5     114
# 8993730  756cfba489fe     114
# 8993731  3260149f499c     114
# 8993732  2b822fe99044     114
# 8993733  1972b960c8b4     114
# 8993734  1d29dd250b98     114
# 8993735  183b73475dd3     114
# ...

# %%
mysub.tail(200)
# Out:
#                    Id  Visits
# 8993706  be4fd4c5da0b  109.96
# 8993707  1e4f74e03574  109.96
# 8993708  0796811b4fe3  109.96
# 8993709  0990196aea5d  109.96
# 8993710  3222d01e18e4  111.64
# 8993711  4a07dfbfcc16  111.64
# 8993712  e1fc9c153a4d  109.96
# 8993713  78f7e09e2b6b  109.96
# 8993714  b7bec7defde7  109.96
# 8993715  bd5f46d6eaac  109.96
# 8993716  1b436c7108eb  109.96
# 8993717  8f57864a709c  111.64
# 8993718  a8f2aa21e501  111.64
# 8993719  85b4305462e7  109.96
# 8993720  360d9cf6d643  126.42
# 8993721  7523ce121ed9  126.42
# 8993722  1cb4fb78a570  126.42
# 8993723  45f55f02687e  124.46
# 8993724  8faa3078d19b  124.46
# 8993725  6627c9e4b49a  126.42
# 8993726  d716d8666920  126.42
# 8993727  0341a9e25cec  126.42
# 8993728  76a98c3a237e  126.42
# 8993729  616484bad8e5  126.42
# 8993730  756cfba489fe  124.46
# 8993731  3260149f499c  124.46
# 8993732  2b822fe99044  126.42
# 8993733  1972b960c8b4  126.42
# 8993734  1d29dd250b98  126.42
# 8993735  183b73475dd3  126.42
# ...
